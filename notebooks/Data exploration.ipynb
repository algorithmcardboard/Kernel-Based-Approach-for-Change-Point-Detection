# %%
# %matplotlib nbagg

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('../data/train/Data_S02_Sess01.csv')

# %%
plt.plot(data[["Fp1"]].as_matrix()[0:10000])
# Out:
# <img src="data:image/png;base64,...">
